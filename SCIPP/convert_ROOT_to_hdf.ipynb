# %%
import uproot
import pandas

# %%
flat_tree = uproot.open('344180ade_cgeeMaker.root')['Nominal']

# %%
print(flat_tree.keys())
# Out:
# ['nJets', 'matchB1', 'matchB2', 'passg10', 'passg15', 'passg20', 'passg25', 'passg35', 'passg40', 'passg45', 'passg50', 'passg60', 'passg70', 'passg80', 'passTrig', 'passg100', 'passg120', 'passVBF0b', 'passVBF18', 'passVBF1b', 'passVBF20', 'passVBF22', 'passVBF2b', 'matchVBF0b', 'passEM13VH', 'passEM15VH', 'passEM18VH', 'passEM20VH', 'passVBF1bs', 'passVBF2bs', 'tagCatExcl', 'passEM22VHI', 'passVBF25g4j', 'passMVAPreSel', 'MCChannelNumber', 'randomRunNumber', 'passVBF1bmv2c10s', 'passVBF2bmv2c10s', 'passVBFbmv2c10s500', 'passVBFbmv2c10s500gsc', 'RunNumber', 'EventNumber', 'BDT', 'zep', 'pTB1', 'pTB2', 'pTBB', 'pTJ1', 'pTJ2', 'pTJ4', 'pTPh', 'zeta', 'etaJ1', 'etaJ2', 'etaJ5', 'pTBal', 'phEta', 'JJasym', 'dEtabb', 'dPhibb', 'dRB1J1', 'dRB1Ph', 'dRB2Ph', 'cenPhJJ', 'hlt_mjj', 'l1_emet', 'pTJ1cen', 'MV2c10B1', 'MV2c10B2', 'arctanbb', 'cosAlpha', 'dEtaBBJJ', 'dPhiBBJJ', 'etaJ1cen', 'hlt_j1pt', 'hlt_j2pt', 'hlt_j3pt', 'hlt_j4pt', 'hlt_j5pt', 'hlt_phpt', 'mindRBPh', 'cosThetaC', 'hlt_mjj_p
# ...

# %%
df = pandas.DataFrame(flat_tree.to_numpy(), columns=flat_tree.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <module>
# ----> 1 df = pandas.DataFrame(flat_tree.to_numpy(), columns=flat_tree.keys())
#
# AttributeError: 'Model_TTree_v20' object has no attribute 'to_numpy'

# %%
df
# Out:
#     nJets  matchB1  matchB2  passg10  passg15  passg20  passg25  passg35  \
# 0     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..    ...      ...      ...      ...      ...      ...      ...      ...
# 92    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 93    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 94    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 95    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 96    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#     passg40  passg45  ...  pTJJ  dEtaJJ  pTJJSF  pTBalSF  dEtaJJSF  dRB1PhSF  \
# ...

# %%
df2 = flat_tree.arrays(flat_tree.keys(), library="pd")

# %%
df2
# Out:
#          nJets  matchB1  matchB2  passg10  passg15  passg20  passg25  passg35  \
# 0            4        0        0        1        1        1        0        0
# 1            4        0        1        1        1        1        1        1
# 2            4        0        0        1        1        1        1        1
# 3            4        1        1        1        1        1        1        1
# 4            6        1        1        1        1        1        1        1
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 2542826      6        0        0        1        1        1        1        1
# 2542827      6        0        0        1        1        1        1        1
# 2542828      4        0        0        1        1        1        1        1
# 2542829      5        0        0        1        1        1        1        0
# 2542830      4        0        0        1        1        1        1        1
#
# ...

# %%
df2.to_hdf('test.hdf',key='df')

# %% [markdown]
# ## Test reading the HDF file back into Python

# %%
import h5py

# %%
input_file = h5py.File('test.hdf','r')
